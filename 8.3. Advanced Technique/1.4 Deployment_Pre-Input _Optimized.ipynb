# %%
import pickle

# %%
sc = pickle.load(open("scaler.sav", "rb"))

# %%
preinput=sc.transform([[1300, 12000, 4000, 0, 1]])
# Out:
# C:\Users\Default.DESKTOP-73FCCDO\Documents\Installations\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
preinput
# Out:
# array([[-1.46755405, -4.33835385, -1.50744257, -0.5       ,  1.30088727]])

# %%
loaded_model=pickle.load(open("finalized_model_svm_opt.sav", 'rb'))
result=loaded_model.predict(preinput)

# %%
result
# Out:
# array([106390.80583631])
